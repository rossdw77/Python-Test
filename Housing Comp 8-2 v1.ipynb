# %%
import pandas as pd
import numpy as np
import datetime 
import os
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rossd\\Kaggle Competitions\\Advanced Regression Housing'

# %% [markdown]
# ## Data Import

# %%
train_data = pd.read_csv('train.csv')
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
for data in train_data.dtypes:
    print(data)
# Out:
# int64
# int64
# object
# float64
# int64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# int64
# int64
# int64
# int64
# object
# object
# object
# object
# object
# float64
# object
# object
# object
# object
# object
# object
# object
# int64
# object
# int64
# int64
# int64
# object
# object
# object
# object
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# object
# int64
# object
# int64
# object
# object
# float64
# object
# int64
# int64
# object
# object
# object
# int64
# int64
# int64
# int64
# int64
# int64
# object
# object
# object
# int64
# int64
# int64
# object
# object
# int64

# %%
train_data.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
train_data.loc[:,train_data.isna().any()]
# Out:
#       LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 0            65.0   NaN    BrkFace       196.0       Gd       TA           No
# 1            80.0   NaN       None         0.0       Gd       TA           Gd
# 2            68.0   NaN    BrkFace       162.0       Gd       TA           Mn
# 3            60.0   NaN       None         0.0       TA       Gd           No
# 4            84.0   NaN    BrkFace       350.0       Gd       TA           Av
# ...           ...   ...        ...         ...      ...      ...          ...
# 1455         62.0   NaN       None         0.0       Gd       TA           No
# 1456         85.0   NaN      Stone       119.0       Gd       TA           No
# 1457         66.0   NaN       None         0.0       TA       Gd           No
# 1458         68.0   NaN       None         0.0       TA       TA           Mn
# 1459         75.0   NaN       None         0.0       TA       TA           No
#
# ...

# %%
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
fig, ax = plt.subplots(figsize = (10,10))
plt.scatter(train_data.YearBuilt, train_data.SalePrice)

# %% [markdown]
# ### Stat Model

# %%
y = train_data['SalePrice']

# %%
X = train_data['YearBuilt']

# %%
X
# Out:
# 0       2003
# 1       1976
# 2       2001
# 3       1915
# 4       2000
#         ...
# 1455    1999
# 1456    1978
# 1457    1941
# 1458    1950
# 1459    1965
# Name: YearBuilt, Length: 1460, dtype: int64

# %%
type(X.iloc[0])
# Out:
# numpy.int64

# %%
len(X)
# Out:
# 1460

# %%
type(y.iloc[0])
# Out:
# numpy.int64

# %%
len(y)
# Out:
# 1460

# %%
y.isna().any()
# Out:
# False

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-3a3731c01495> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 lin_reg = LinearRegression()
# ----> 3 lin_reg.fit(X, y)
#       4 lin_reg.intercept_, lin_reg.coef_
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...

# %%
import statsmodels.formula.api as smf

dat1=pd.DataFrame({'SalesPrice':y, 'YearBuilt':X})

mod2=smf.ols(formula='SalesPrice~YearBuilt',data=dat1).fit()
mod2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             SalesPrice   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     548.7
# Date:                Tue, 02 Aug 2022   Prob (F-statistic):          2.99e-103
# Time:                        21:49:56   Log-Likelihood:                -18311.
# No. Observations:                1460   AIC:                         3.663e+04
# Df Residuals:                    1458   BIC:                         3.664e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -2.53e+06   1.16e+05    -21.858      0.000   -2.76e+06    -2.3e+06
# ...

# %%
dat1=pd.DataFrame({'SalesPrice':y, 'YearBuilt':X})
dat1
# Out:
#       SalesPrice  YearBuilt
# 0         208500       2003
# 1         181500       1976
# 2         223500       2001
# 3         140000       1915
# 4         250000       2000
# ...          ...        ...
# 1455      175000       1999
# 1456      210000       1978
# 1457      266500       1941
# 1458      142125       1950
# 1459      147500       1965
#
# [1460 rows x 2 columns]
